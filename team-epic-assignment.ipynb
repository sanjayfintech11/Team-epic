# %% [markdown]
# # Team Epic- Insights from the given Data
#
# Use the "Run" button to execute the code.

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ## Installing all the necesary libraries and then coveting the JSON object into Dataframe

# %%
# !pip install opendatasets --upgrade --quiet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import opendatasets as od
import folium
import plotly.express as px
# %matplotlib inline
sns.set_style("whitegrid")

# %%
import pandas as pd
df=pd.read_json('data-TllBJzPFimbSBz_TSK06e (1).json')
#data-TllBJzPFimbSBz_TSK06e.json

# %% [markdown]
# ## Printing the Dataframe below

# %%
df
# Out:
#                     name           phone                              email  \
# 0       Preston Browning  1-643-668-4991      auctor.mauris.vel@icloud.couk
# 1           Zelda Barton  1-515-181-2957            mollis.duis@icloud.couk
# 2   Christian Mccullough  1-362-238-6643    risus.donec.egestas@hotmail.edu
# 3            Alice Drake  (826) 217-2852     consectetuer.ipsum@outlook.edu
# 4           Cameron Kent  1-233-855-1424             sapien.nunc@icloud.com
# ..                   ...             ...                                ...
# 95          Paki Harrell  (241) 375-4115                 nec@protonmail.edu
# 96        Ivory Stafford  (256) 628-1012             magna.sed.eu@yahoo.net
# 97       Connor Atkinson  (911) 853-1336           suspendisse@hotmail.couk
# 98        Kylynn Perkins  (432) 577-6565             volutpat.nunc@yahoo.ca
# 99            Olga Evans  (648) 965-4959  a.felis.ullamcorper@protonmail.ca
#
# ...

# %% [markdown]
# ## Looks like the above data doesnt have much of missing values, Lets proceed with Data cleaning, Preprocessing, EDA and feature engineering if necessary based on the target variable

# %%
df.head()
# Out:
#                    name           phone                            email  \
# 0      Preston Browning  1-643-668-4991    auctor.mauris.vel@icloud.couk
# 1          Zelda Barton  1-515-181-2957          mollis.duis@icloud.couk
# 2  Christian Mccullough  1-362-238-6643  risus.donec.egestas@hotmail.edu
# 3           Alice Drake  (826) 217-2852   consectetuer.ipsum@outlook.edu
# 4          Cameron Kent  1-233-855-1424           sapien.nunc@icloud.com
#
#                       address  customer priority        country  \
# 0   778-7493 Vulputate Avenue                  2          Italy
# 1           5714 Molestie Rd.                  5          China
# 2        499-7104 Sed, Avenue                  3  United States
# 3      Ap #135-682 Mauris Rd.                  2   South Africa
# 4  Ap #895-5206 Ultrices. Rd.                  4    Netherlands
#
#             region  postalZip  currency                         iban  \
# ...

# %%
df.tail()
# Out:
#                name           phone                              email  \
# 95     Paki Harrell  (241) 375-4115                 nec@protonmail.edu
# 96   Ivory Stafford  (256) 628-1012             magna.sed.eu@yahoo.net
# 97  Connor Atkinson  (911) 853-1336           suspendisse@hotmail.couk
# 98   Kylynn Perkins  (432) 577-6565             volutpat.nunc@yahoo.ca
# 99       Olga Evans  (648) 965-4959  a.felis.ullamcorper@protonmail.ca
#
#                           address  customer priority      country  \
# 95  P.O. Box 350, 8283 Auctor St.                  5      Vietnam
# 96    P.O. Box 729, 252 Nibh Road                  3  Netherlands
# 97           388-2939 Dui. Avenue                  5      Austria
# 98      Ap #150-2845 Fames Street                  5       France
# 99        Ap #547-2528 Magna. Ave                  2    Indonesia
#
#                 region postalZip  currency                          iban  \
# ...

# %%
df.describe()
# Out:
#        customer priority
# count         100.000000
# mean            3.220000
# std             1.508093
# min             1.000000
# 25%             2.000000
# 50%             3.000000
# 75%             5.000000
# max             5.000000

# %%
print(df.shape)
print(df.columns)
# Out:
# (100, 13)
# Index(['name', 'phone', 'email', 'address', 'customer priority', 'country',
#        'region', 'postalZip', 'currency', 'iban', 'Card', 'Account Status',
#        'Account type'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               100 non-null    object
#  1   phone              100 non-null    object
#  2   email              100 non-null    object
#  3   address            100 non-null    object
#  4   customer priority  100 non-null    int64
#  5   country            100 non-null    object
#  6   region             100 non-null    object
#  7   postalZip          100 non-null    object
#  8   currency           100 non-null    object
#  9   iban               100 non-null    object
#  10  Card               100 non-null    object
#  11  Account Status     100 non-null    object
#  12  Account type       100 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 10.3+ KB
# None

# %%
df["Card"] = df["Card"].astype("int64")

# %%
df["currency"].value_counts()
# Out:
# $5036.87    1
# $6234.72    1
# $1442.66    1
# $9533.16    1
# $4795.70    1
#            ..
# $8306.72    1
# $3133.15    1
# $2143.51    1
# $2121.41    1
# $8558.63    1
# Name: currency, Length: 100, dtype: int64

# %%
df.size
# Out:
# 1300

# %%
df.sample( )
# Out:
#              name           phone                  email  \
# 31  Jorden Kelley  (219) 565-2631  fringilla@hotmail.net
#
#                       address  customer priority country   region postalZip  \
# 31  Ap #374-6817 Sagittis Av.                  2   Chile  Alberta    636522
#
#     currency                  iban              Card Account Status  \
# 31  $9690.68  EE283818163866677214  4917275918788555         Active
#
#    Account type
# 31      Premium

# %%
df.isnull( ).sum( )
# Out:
# name                 0
# phone                0
# email                0
# address              0
# customer priority    0
# country              0
# region               0
# postalZip            0
# currency             0
# iban                 0
# Card                 0
# Account Status       0
# Account type         0
# dtype: int64

# %%
df.nunique( )
# Out:
# name                 100
# phone                100
# email                100
# address              100
# customer priority      5
# country               34
# region                92
# postalZip            100
# currency             100
# iban                 100
# Card                 100
# Account Status         2
# Account type           2
# dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'phone', 'email', 'address', 'customer priority', 'country',
#        'region', 'postalZip', 'currency', 'iban', 'Card', 'Account Status',
#        'Account type'],
#       dtype='object')

# %% [markdown]
# ## Dropping NA values if any from the dataset

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (100, 13)

# %%
df.isna().head()
# Out:
#     name  phone  email  address  customer priority  country  region  \
# 0  False  False  False    False              False    False   False
# 1  False  False  False    False              False    False   False
# 2  False  False  False    False              False    False   False
# 3  False  False  False    False              False    False   False
# 4  False  False  False    False              False    False   False
#
#    postalZip  currency   iban   Card  Account Status  Account type
# 0      False     False  False  False           False         False
# 1      False     False  False  False           False         False
# 2      False     False  False  False           False         False
# 3      False     False  False  False           False         False
# 4      False     False  False  False           False         False

# %%
duplicates=df.duplicated()
duplicates.sum()
# Out:
# 0

# %%
df['Account Status'].value_counts()
# Out:
# Active      54
# Inactive    46
# Name: Account Status, dtype: int64

# %%
df['Account type'].value_counts()
#Building a pie chart
#Plotting a histogram for the currency
#Region-Country wise plotting- Use folium for geo- heat maps- country wise/Bar plots/stacked bar
#Customer priority bar plot- histogram- Pie chart
# Out:
# Premium    55
# Basic      45
# Name: Account type, dtype: int64

# %%
df.corr()
# Out:
#                    customer priority
# customer priority                1.0

# %%
df.dtypes
# Out:
# name                 object
# phone                object
# email                object
# address              object
# customer priority     int64
# country              object
# region               object
# postalZip            object
# currency             object
# iban                 object
# Card                 object
# Account Status       object
# Account type         object
# dtype: object

# %%
df.interpolate()
# Out:
#                     name           phone                              email  \
# 0       Preston Browning  1-643-668-4991      auctor.mauris.vel@icloud.couk
# 1           Zelda Barton  1-515-181-2957            mollis.duis@icloud.couk
# 2   Christian Mccullough  1-362-238-6643    risus.donec.egestas@hotmail.edu
# 3            Alice Drake  (826) 217-2852     consectetuer.ipsum@outlook.edu
# 4           Cameron Kent  1-233-855-1424             sapien.nunc@icloud.com
# ..                   ...             ...                                ...
# 95          Paki Harrell  (241) 375-4115                 nec@protonmail.edu
# 96        Ivory Stafford  (256) 628-1012             magna.sed.eu@yahoo.net
# 97       Connor Atkinson  (911) 853-1336           suspendisse@hotmail.couk
# 98        Kylynn Perkins  (432) 577-6565             volutpat.nunc@yahoo.ca
# 99            Olga Evans  (648) 965-4959  a.felis.ullamcorper@protonmail.ca
#
# ...

# %% [markdown]
# - Which customers has the highest balance and which region more customers are there
# - No. of active accounts and premium
# - How many students and how many professionals- state of these accounts
# - Priority of customers
# - How many inactive accounts and generate a report
# - In one country- Are there many regions and customers coming from same or different regions??

# %%
df.drop_duplicates()
# Out:
#                     name           phone                              email  \
# 0       Preston Browning  1-643-668-4991      auctor.mauris.vel@icloud.couk
# 1           Zelda Barton  1-515-181-2957            mollis.duis@icloud.couk
# 2   Christian Mccullough  1-362-238-6643    risus.donec.egestas@hotmail.edu
# 3            Alice Drake  (826) 217-2852     consectetuer.ipsum@outlook.edu
# 4           Cameron Kent  1-233-855-1424             sapien.nunc@icloud.com
# ..                   ...             ...                                ...
# 95          Paki Harrell  (241) 375-4115                 nec@protonmail.edu
# 96        Ivory Stafford  (256) 628-1012             magna.sed.eu@yahoo.net
# 97       Connor Atkinson  (911) 853-1336           suspendisse@hotmail.couk
# 98        Kylynn Perkins  (432) 577-6565             volutpat.nunc@yahoo.ca
# 99            Olga Evans  (648) 965-4959  a.felis.ullamcorper@protonmail.ca
#
# ...

# %% [markdown]
# ## No. of active accounts- Account Status

# %%
#No. of active accounts and premium
w = df.groupby(['Account Status']).size()
fig = px.pie(values=w.values, names=w.index, title='Customer Account Status', width=600, height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## No. of type of accounts- Basic and premium

# %%
w1 = df.groupby(['Account type']).size()
w1
# Out:
# Account type
# Basic      45
# Premium    55
# dtype: int64

# %%
#No. of active accounts and premium
fig = px.pie(values=w1.values, names=w1.index, title='Customer Account Type', width=600, height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df3=df[['country']]
df3
# Out:
#           country
# 0           Italy
# 1           China
# 2   United States
# 3    South Africa
# 4     Netherlands
# ..            ...
# 95        Vietnam
# 96    Netherlands
# 97        Austria
# 98         France
# 99      Indonesia
#
# [100 rows x 1 columns]

# %%
df3 = df.country.value_counts().head().sort_values(ascending = True)

# %%
df3
# Out:
# Costa Rica        5
# Poland            5
# Italy             6
# United Kingdom    6
# Netherlands       7
# Name: country, dtype: int64

# %%
df3=pd.DataFrame(df3)
df3
# Out:
#                 country
# Costa Rica            5
# Poland                5
# Italy                 6
# United Kingdom        6
# Netherlands           7

# %% [markdown]
# ## Number of customers per country

# %%
df3 = df[['country']]
df3 = df3.country.value_counts().head().sort_values(ascending = True)
df3 = pd.DataFrame(df3)

# %%
df3.plot(kind='barh',figsize=(12,8));
plt.xlabel('Number of Customers per country', fontsize= 15)
plt.ylabel('Country Name', fontsize= 15)
plt.title('Highest number of customers by country',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Highest number of customers by country')

# %% [markdown]
# ## Which customers has the highest balance

# %%
 df
# Out:
#                     name           phone                              email  \
# 0       Preston Browning  1-643-668-4991      auctor.mauris.vel@icloud.couk
# 1           Zelda Barton  1-515-181-2957            mollis.duis@icloud.couk
# 2   Christian Mccullough  1-362-238-6643    risus.donec.egestas@hotmail.edu
# 3            Alice Drake  (826) 217-2852     consectetuer.ipsum@outlook.edu
# 4           Cameron Kent  1-233-855-1424             sapien.nunc@icloud.com
# ..                   ...             ...                                ...
# 95          Paki Harrell  (241) 375-4115                 nec@protonmail.edu
# 96        Ivory Stafford  (256) 628-1012             magna.sed.eu@yahoo.net
# 97       Connor Atkinson  (911) 853-1336           suspendisse@hotmail.couk
# 98        Kylynn Perkins  (432) 577-6565             volutpat.nunc@yahoo.ca
# 99            Olga Evans  (648) 965-4959  a.felis.ullamcorper@protonmail.ca
#
# ...

# %% [markdown]
# ## No. of customers as per the priority rating(1-5)

# %%
df["customer priority"].value_counts()
# Out:
# 5    31
# 2    19
# 1    18
# 3    17
# 4    15
# Name: customer priority, dtype: int64

# %%
df["region"].value_counts()
# Out:
# Oost-Vlaanderen    2
# North West         2
# Irkutsk Oblast     2
# Galicia            2
# MaÅopolskie        2
#                   ..
# Alberta            1
# Haute-Normandie    1
# Sumy oblast        1
# Lampung            1
# Báº¯c Káº¡n            1
# Name: region, Length: 92, dtype: int64

# %%
df["country"].value_counts()
# Out:
# Netherlands           7
# Italy                 6
# United Kingdom        6
# Costa Rica            5
# Poland                5
# Ukraine               5
# Peru                  4
# Norway                4
# South Africa          4
# United States         3
# Belgium               3
# New Zealand           3
# Mexico                3
# Russian Federation    3
# China                 3
# Vietnam               3
# Nigeria               3
# Philippines           3
# Germany               3
# Indonesia             2
# Canada                2
# Spain                 2
# Australia             2
# France                2
# India                 2
# Chile                 2
# Austria               2
# Singapore             2
# Ireland               1
# Sweden                1
# Turkey                1
# Colombia              1
# Pakistan              1
# South Korea           1
# Name: country, dtype: int64

# %%
df["postalZip"].value_counts()
# Out:
# 09320     1
# 6671      1
# 53654     1
# 8223      1
# 277838    1
#          ..
# 391874    1
# 872152    1
# 83044     1
# 5535      1
# 64541     1
# Name: postalZip, Length: 100, dtype: int64

# %%
df["currency"].value_counts()
# Out:
# $5036.87    1
# $6234.72    1
# $1442.66    1
# $9533.16    1
# $4795.70    1
#            ..
# $8306.72    1
# $3133.15    1
# $2143.51    1
# $2121.41    1
# $8558.63    1
# Name: currency, Length: 100, dtype: int64

# %%
df.min()
# Out:
# name                              Abel Juarez
# phone                          (112) 553-3388
# email                a.auctor.non@icloud.couk
# address                       111-2612 Ut Ave
# customer priority                           1
# country                             Australia
# region                                   Aceh
# postalZip                             0262 EI
# currency                             $1120.40
# iban                  AE292775966739354881481
# Card                        2014 392937 52449
# Account Status                         Active
# Account type                            Basic
# dtype: object

# %%
df.max()
# Out:
# name                                Zena Pennington
# phone                                1-996-970-7509
# email                        volutpat.nunc@yahoo.ca
# address              P.O. Box 960, 1121 Aliquam St.
# customer priority                                 5
# country                                     Vietnam
# region                                     ZhÅngnÃ¡n
# postalZip                                  TO72 4GN
# currency                                   $9925.46
# iban                       VG4896152644578643383777
# Card                              676796 3278996485
# Account Status                             Inactive
# Account type                                Premium
# dtype: object

# %% [markdown]
# ## Max account balance a customer has from the dataset

# %%
df["currency"].max()
# Out:
# '$9925.46'

# %% [markdown]
# ## Min account balance a customer has from the dataset

# %%
df["currency"].min()
# Out:
# '$1120.40'

# %%
df
# Out:
#                     name           phone                              email  \
# 0       Preston Browning  1-643-668-4991      auctor.mauris.vel@icloud.couk
# 1           Zelda Barton  1-515-181-2957            mollis.duis@icloud.couk
# 2   Christian Mccullough  1-362-238-6643    risus.donec.egestas@hotmail.edu
# 3            Alice Drake  (826) 217-2852     consectetuer.ipsum@outlook.edu
# 4           Cameron Kent  1-233-855-1424             sapien.nunc@icloud.com
# ..                   ...             ...                                ...
# 95          Paki Harrell  (241) 375-4115                 nec@protonmail.edu
# 96        Ivory Stafford  (256) 628-1012             magna.sed.eu@yahoo.net
# 97       Connor Atkinson  (911) 853-1336           suspendisse@hotmail.couk
# 98        Kylynn Perkins  (432) 577-6565             volutpat.nunc@yahoo.ca
# 99            Olga Evans  (648) 965-4959  a.felis.ullamcorper@protonmail.ca
#
# ...

# %%
df[df['email'].str.match('.*.edu$')]
# Out:
#                     name           phone                            email  \
# 2   Christian Mccullough  1-362-238-6643  risus.donec.egestas@hotmail.edu
# 3            Alice Drake  (826) 217-2852   consectetuer.ipsum@outlook.edu
# 15        Philip Beasley  (579) 954-3571          luctus.lobortis@aol.edu
# 17         Plato Hendrix  (560) 853-2103           aliquam.eu@outlook.edu
# 18           Flavia Wall  1-143-898-9814              lacinia@outlook.edu
# 22        Calvin Robbins  (264) 788-0006               sit@protonmail.edu
# 30         Rahim Lindsay  1-720-995-1128           elit.etiam@outlook.edu
# 44         Emery Gilmore  1-996-970-7509       turpis.aliquam@hotmail.edu
# 58      Samson Mccormick  (867) 820-7637                   et@hotmail.edu
# 61      Geraldine Branch  1-724-877-7653                sed.eu@icloud.edu
# 73          Orla Calhoun  (677) 679-1380         metus.sit@protonmail.edu
# 76           Dahlia Nash  (821) 213-9018            neque.morbi@yahoo.edu
# ...

# %% [markdown]
# ## Out of the total 100 customers, 16 customers are students studying in a School/University

# %%
df[df['email'].str.match('.*edu$')].count()
# Out:
# name                 16
# phone                16
# email                16
# address              16
# customer priority    16
# country              16
# region               16
# postalZip            16
# currency             16
# iban                 16
# Card                 16
# Account Status       16
# Account type         16
# dtype: int64

# %%
df[df['email'].str.match('.*@hotmail.edu$')]
# Out:
#                     name           phone                            email  \
# 2   Christian Mccullough  1-362-238-6643  risus.donec.egestas@hotmail.edu
# 44         Emery Gilmore  1-996-970-7509       turpis.aliquam@hotmail.edu
# 58      Samson Mccormick  (867) 820-7637                   et@hotmail.edu
# 77      Channing Emerson  1-667-772-0745                donec@hotmail.edu
#
#                     address  customer priority        country       region  \
# 2      499-7104 Sed, Avenue                  3  United States        Yukon
# 44            863 Ante. St.                  2          Italy  Tver Oblast
# 58   Ap #295-8920 Enim. Rd.                  2        Belgium        Konya
# 77  728-9151 Auctor. Street                  3      Indonesia     Salzburg
#
#       postalZip  currency                         iban                 Card  \
# 2     7533-8745  $9281.37  MC6572183791372833731536582      361387628471721
# ...

# %% [markdown]
# ## In the interest of time, and also to ask more questions, more Feature engineering is required based on the new target variables, I think I was able to come up with some basic simple questions. If I can get more info on the data and may be create more columns, We can analyze and visulize it accordingly. Am open to further discussion from the stakeholders.

# %%
email= df['email']
for i in email:
    if email.str.contains(pat='@hotmail.edu')=="True":
        needac.append(i)

# %%
df.dropna()

mail_list = []
pattern = r'.(@hotmail\.edu)'
for i in list(df):
    matched = re.search(pattern, i)
    if matched:
        mail_list.append(i)
